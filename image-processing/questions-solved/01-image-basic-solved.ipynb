# %% [markdown]
# ----------------------------------
#
# # Visão Geral
#
# - Exercícios: 15 min
#
# ### Requisitos:
# - Conhecidos básicos da linguagem Python
# - Leitura da lição de noções básicas de imagens digitais
#
# ---------------------------

# %% [markdown]
# # Questões
# ---

# %% [markdown]
# ### 1. Quantas cores podem ser representadas com o modelo de cor RGB de 24 bits?

# %% [markdown]
# Com um total de 24 bits ativos ou não, o modelo cor RGB de 24 bits pode representar 16.777.216.
#
# 2²⁴ = 16.777.216

# %% [markdown]
# ### 2. Transforme a imagem vermelho.jpg, modifique as cores do pixels da imagem para a cor preta.

# %%
# Importação da biblioteca OpenCV
import cv2
import matplotlib.pyplot as plt

imagem = cv2.imread('../../figures/vermelho.jpg')
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# y eixo da altura da imagem
# x eixo da largura da imagem
for y in range(0, imagem.shape[0]):
    for x in range(0, imagem.shape[1]):
        # atribuindo o maior valor para o canal green
        imagem[y, x] = (0, 0, 0) # red, green, blue

plt.imshow(imagem)

# %% [markdown]
# ### 3. Desenhe um quadrado azul (50x50 pixels) no centro da imagem vermelho.jpg.

# %%
# Importação da biblioteca OpenCV
import cv2
import matplotlib.pyplot as plt

imagem = cv2.imread('../../figures/vermelho.jpg')
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

largura = imagem.shape[1]
altura = imagem.shape[0]

x = (largura // 2) - 25
y = (altura // 2) - 25

imagem[y:y+50, x:x+50] = (0, 0, 255) # red, green, blue

print(largura, altura)

plt.imshow(imagem)
# Out:
# 300 225
